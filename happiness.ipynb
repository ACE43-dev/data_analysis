# %%
import pandas as pd 
h21=pd.read_csv("dataset/world-happiness-report-2021.csv")
h24=pd.read_csv("dataset/world-happiness-report-2024.csv")

# %%
h21.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
h24.head()
# Out:
#   Country name            Regional indicator  Ladder score  upperwhisker  \
# 0      Finland                Western Europe         7.741         7.815
# 1      Denmark                Western Europe         7.583         7.665
# 2      Iceland                Western Europe         7.525         7.618
# 3       Sweden                Western Europe         7.344         7.422
# 4       Israel  Middle East and North Africa         7.341         7.405
#
#    lowerwhisker  Log GDP per capita  Social support  Healthy life expectancy  \
# 0         7.667               1.844           1.572                    0.695
# 1         7.500               1.908           1.520                    0.699
# 2         7.433               1.881           1.617                    0.718
# 3         7.267               1.878           1.501                    0.724
# 4         7.277               1.803           1.513                    0.740
#
# ...

# %%
h21['year'] = 2021

# %%
h24['year'] = 2024

# %%
h21.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
h24.head()
# Out:
#   Country name            Regional indicator  Ladder score  upperwhisker  \
# 0      Finland                Western Europe         7.741         7.815
# 1      Denmark                Western Europe         7.583         7.665
# 2      Iceland                Western Europe         7.525         7.618
# 3       Sweden                Western Europe         7.344         7.422
# 4       Israel  Middle East and North Africa         7.341         7.405
#
#    lowerwhisker  Log GDP per capita  Social support  Healthy life expectancy  \
# 0         7.667               1.844           1.572                    0.695
# 1         7.500               1.908           1.520                    0.699
# 2         7.433               1.881           1.617                    0.718
# 3         7.267               1.878           1.501                    0.724
# 4         7.277               1.803           1.513                    0.740
#
# ...

# %%
df = pd.concat(objs=[h21,h24],axis=0,join="inner")

# %%
df.head()
df.shape
# Out:
# (292, 12)

# %%
h21.shape
# Out:
# (149, 21)

# %%
df.head()
# Out:
#   Country name Regional indicator  Ladder score  upperwhisker  lowerwhisker  \
# 0      Finland     Western Europe         7.842         7.904         7.780
# 1      Denmark     Western Europe         7.620         7.687         7.552
# 2  Switzerland     Western Europe         7.571         7.643         7.500
# 3      Iceland     Western Europe         7.554         7.670         7.438
# 4  Netherlands     Western Europe         7.464         7.518         7.410
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption  Dystopia + residual  year
# ...

# %%
df.tail()
# Out:
#          Country name            Regional indicator  Ladder score  \
# 138  Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 139      Sierra Leone            Sub-Saharan Africa         3.245
# 140           Lesotho            Sub-Saharan Africa         3.186
# 141           Lebanon  Middle East and North Africa         2.707
# 142       Afghanistan                    South Asia         1.721
#
#      upperwhisker  lowerwhisker  Social support  Healthy life expectancy  \
# 138         3.462         3.128           0.665                    0.262
# 139         3.366         3.124           0.566                    0.253
# 140         3.469         2.904           0.851                    0.000
# 141         2.797         2.616           0.577                    0.556
# 142         1.775         1.667           0.000                    0.242
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# ...

# %%
a=df.pivot(
    index=["Country name"],columns=["year"],values=['Healthy life expectancy']
)

# %%
a.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 154 entries, Afghanistan to Zimbabwe
# Data columns (total 2 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   (Healthy life expectancy, 2021)  149 non-null    float64
#  1   (Healthy life expectancy, 2024)  140 non-null    float64
# dtypes: float64(2)
# memory usage: 3.6+ KB

# %%
a
# Out:
#              Healthy life expectancy
# year                            2021   2024
# Country name
# Afghanistan                   52.493  0.242
# Albania                       68.999  0.638
# Algeria                       66.005  0.568
# Argentina                     69.000  0.585
# Armenia                       67.055  0.603
# ...                              ...    ...
# Venezuela                     66.700  0.491
# Vietnam                       68.034  0.539
# Yemen                         57.122  0.293
# Zambia                        55.809  0.264
# Zimbabwe                      56.201  0.232
#
# [154 rows x 2 columns]

# %%
a.iloc[:,1] = a.iloc[:,1] *100

# %%
a
# Out:
#              Healthy life expectancy
# year                            2021  2024
# Country name
# Afghanistan                   52.493  24.2
# Albania                       68.999  63.8
# Algeria                       66.005  56.8
# Argentina                     69.000  58.5
# Armenia                       67.055  60.3
# ...                              ...   ...
# Venezuela                     66.700  49.1
# Vietnam                       68.034  53.9
# Yemen                         57.122  29.3
# Zambia                        55.809  26.4
# Zimbabwe                      56.201  23.2
#
# [154 rows x 2 columns]

# %%
a.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Argentina', 'Armenia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        ...
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay',
#        'Uzbekistan', 'Venezuela', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='str', name='Country name', length=154)

# %%
a.head(30).plot()
# Out:
# <Axes: xlabel='Country name'>

# %%
df.to_csv("analysedData/happiness.csv")

# %%
pivot_df = df.pivot(index='Country name', columns='year', values='Ladder score')
change = pivot_df[2024]-pivot_df[2021]
change
# Out:
# Country name
# Afghanistan   -0.802
# Albania        0.187
# Algeria        0.477
# Argentina      0.259
# Armenia        0.172
#                ...
# Venezuela      0.715
# Vietnam        0.632
# Yemen         -0.097
# Zambia        -0.571
# Zimbabwe       0.196
# Length: 154, dtype: float64

# %%
change.isnull().sum()
type(change)
change.dropna(inplace=True)

# %%
change.sort_values(ascending=True).iloc[[0,1,2,3,4]]
# Out:
# Country name
# Lebanon       -1.877
# Bangladesh    -1.139
# Afghanistan   -0.802
# Ghana         -0.799
# Comoros       -0.723
# dtype: float64

# %%
change.sort_values(ascending=False).iloc[[0,1,2,3,4]]
# Out:
# Country name
# Kuwait       0.845
# Venezuela    0.715
# China        0.634
# Vietnam      0.632
# Malaysia     0.591
# dtype: float64

# %%
print(change[change.index=="India"])
# Out:
# Country name
# India    0.235
# dtype: float64
